# %% [markdown]
# # Modeling and solving search problems
#
# Consider the following river crossing puzzle:
#
# ## Jealous Husbands Problem with an Island
#
# There are n couples: $(𝐻_1,𝑊_1)$, $(𝐻_2,𝑊_2)$, …, $(𝐻_𝑛,𝑊_𝑛)$  where $𝐻_𝑖$ is husband $𝑖$ and $𝑊_𝑖$ is wife $𝑖$.
#
# They need to cross from the left bank of a river to the right bank.
#
# There is a boat that can carry at most two people at a time.
#
# Important: There is an island midway between the left and right banks. The boat can stop at the island.
#
# Rules:
#
# 1. Jealousy constraint: No wife may ever be in the presence of another husband (on any shore or the island or in the boat) unless her own husband is also present. Otherwise, fights (and failures) occur.
#
# 2. The boat needs at least one person to operate (no remote-controlled trips).
#
# 3. The boat can travel between:
#
#             Left bank ↔ Island
#
#             Island ↔ Right bank
#
# 4. All people, including the boat, start at the left bank.
#
# Goal: get everyone (husbands and wives) safely to the right bank, obeying all the rules.
#
#
# ## Tasks:
#
# 1. Put the problem in a form of a search tree: root, nodes, solution and rules for constructing the childrens.
# 2. Solve it using a classic DFS
# 3. Solve it using a classic Back-tracking.
# 4. Solve it using the A* method.

# %%
# imports:
from itertools import combinations
from heapq import heappush, heappop

# %%
# Task 1:
NUM_COUPLES = 3
HUSBANDS = {f"H{i}" for i in range(1, NUM_COUPLES + 1)}
WIVES = {f"W{i}" for i in range(1, NUM_COUPLES + 1)}
EVERYONE = HUSBANDS | WIVES
BOAT_POS = ["left", "island", "right"]

class State:
    def __init__(self, left, island, right, boat_pos):
        self.left = left
        self.island = island
        self.right = right
        self.boat_pos = boat_pos

    def __repr__(self):
        return f"State(L={self.left}, I={self.island}, R={self.right}, boat={self.boat_pos})"

    def is_goal(self):
        return len(self.right) == len(EVERYONE) and self.boat_pos == "right"

    def copy(self):
        return State(
            left=self.left.copy(),
            island=self.island.copy(),
            right=self.right.copy(),
            boat_pos=self.boat_pos
        )

    def __eq__(self, other):
        return (
            isinstance(other, State) and
            self.left == other.left and
            self.island == other.island and
            self.right == other.right and
            self.boat_pos == other.boat_pos
        )

    def __hash__(self):
        return hash((frozenset(self.left), frozenset(self.island), frozenset(self.right), self.boat_pos))
    
    def is_valid(self, boat_passengers):
        return (
            is_group_valid(self.left) and
            is_group_valid(self.island) and
            is_group_valid(self.right) and
            is_group_valid(boat_passengers)
        )
    
    def get_adjacent_boat_positions(self):
        if self.boat_pos == "left" or self.boat_pos == "right":
            return ["island"]
        elif self.boat_pos == "island":
            return ["left", "right"]
        return []
    
    def generate_children(self):
        possible_passengers = []
        for i in range(1, 3):
            possible_passengers.extend(combinations(getattr(self, self.boat_pos), i))

        children = []
        for passengers in possible_passengers:
            passengers = set(passengers)
            for destination in self.get_adjacent_boat_positions():
                new_state = self.copy()
                getattr(new_state, self.boat_pos).difference_update(passengers)
                getattr(new_state, destination).update(passengers)
                new_state.boat_pos = destination
                if new_state.is_valid(passengers):
                    children.append((new_state, passengers))

        return children

def is_group_valid(group):
    for i in range(1, NUM_COUPLES + 1):
        wife = f"W{i}"
        husband = f"H{i}"
        other_husbands = {p for p in group if p.startswith("H") and p != husband}
        if wife in group and husband not in group and other_husbands:
            return False
    return True

initial_state = State(
    left=EVERYONE,
    island=set(),
    right=set(),
    boat_pos="left"
)

# %%
# Task 2:    
def dfs(initial_state: State):
    stack = [(initial_state, [])]
    visited = set()

    while stack:
        current_state, path = stack.pop()

        if current_state in visited:
            continue
        visited.add(current_state)

        if current_state.is_goal():
            print("Goal reached!\n")
            print(f"Initial state:\n{initial_state}\n")
            for step_num, (state, move) in enumerate(path, 1):
                print(f"Step {step_num}: Move {move} - {state}")
            print(f"\nFinal state:\n{current_state}")
            return 

        for child_state, passengers in current_state.generate_children():
            stack.append((child_state, path + [(child_state, passengers)]))

    print("No solution found.")

dfs(initial_state)
# Out:
# Goal reached!
#
# Initial state:
# State(L={'H2', 'W3', 'W1', 'H1', 'W2', 'H3'}, I=set(), R=set(), boat=left)
#
# Step 1: Move {'W1', 'W2'} - State(L={'H2', 'W3', 'H1', 'H3'}, I={'W1', 'W2'}, R=set(), boat=island)
# Step 2: Move {'W1', 'W2'} - State(L={'H2', 'W3', 'H1', 'H3'}, I=set(), R={'W1', 'W2'}, boat=right)
# Step 3: Move {'W2'} - State(L={'H2', 'W3', 'H1', 'H3'}, I={'W2'}, R={'W1'}, boat=island)
# Step 4: Move {'W2'} - State(L={'H2', 'W3', 'H1', 'W2', 'H3'}, I=set(), R={'W1'}, boat=left)
# Step 5: Move {'W3', 'H3'} - State(L={'H2', 'H1', 'W2'}, I={'W3', 'H3'}, R={'W1'}, boat=island)
# Step 6: Move {'H3'} - State(L={'H2', 'H1', 'W2', 'H3'}, I={'W3'}, R={'W1'}, boat=left)
# Step 7: Move {'H1', 'H3'} - State(L={'H2', 'W2'}, I={'W3', 'H1', 'H3'}, R={'W1'}, boat=island)
# Step 8: Move {'H1', 'H3'} - State(L={'H2', 'W2'}, I={'W3'}, R={'W1', 'H1', 'H3'}, boat=right)
# Step 9: Move {'H3'} - State(L={'H2', 'W2'}, I={'W3', 'H3'}, R={'W1', 'H1'}, boat=island)
# Step 10: Move {'W3', 'H3'} - State(L={'H2', 'W2'}, I=set(), R={'W3', 'W1', 'H1', 'H3'}, boat=right)
# Step 11: Move {'H1', 'H3'} - State(L={'H2', 'W2'}, I={'H1', 'H3'}, R={'W3', 'W1'}, boat=island)
# Step 12: Move {'H1', 'H3'} - State(L={'H2', 'H1', 'W2', 'H3'}, I=set(), R={'W1', 'W3'}, boat=left)
# Step 13: Move {'H2', 'W2'} - State(L={'H1', 'H3'}, I={'H2', 'W2'}, R={'W1', 'W3'}, boat=island)
# Step 14: Move {'H2'} - State(L={'H2', 'H1', 'H3'}, I={'W2'}, R={'W1', 'W3'}, boat=left)
# Step 15: Move {'H2', 'H3'} - State(L={'H1'}, I={'H2', 'W2', 'H3'}, R={'W1', 'W3'}, boat=island)
# Step 16: Move {'H2', 'W2'} - State(L={'H2', 'H1', 'W2'}, I={'H3'}, R={'W1', 'W3'}, boat=left)
# Step 17: Move {'H2', 'H1'} - State(L={'W2'}, I={'H2', 'H1', 'H3'}, R={'W1', 'W3'}, boat=island)
# Step 18: Move {'H1', 'H3'} - State(L={'W2'}, I={'H2'}, R={'W1', 'W3', 'H1', 'H3'}, boat=right)
# Step 19: Move {'W3', 'H3'} - State(L={'W2'}, I={'H2', 'W3', 'H3'}, R={'W1', 'H1'}, boat=island)
# Step 20: Move {'H2', 'H3'} - State(L={'W2'}, I={'W3'}, R={'W1', 'H2', 'H1', 'H3'}, boat=right)
# Step 21: Move {'H3'} - State(L={'W2'}, I={'W3', 'H3'}, R={'W1', 'H2', 'H1'}, boat=island)
# Step 22: Move {'W3', 'H3'} - State(L={'W2'}, I=set(), R={'H2', 'W3', 'W1', 'H1', 'H3'}, boat=right)
# Step 23: Move {'W1', 'H1'} - State(L={'W2'}, I={'W1', 'H1'}, R={'H2', 'W3', 'H3'}, boat=island)
# Step 24: Move {'H1'} - State(L={'W2'}, I={'W1'}, R={'H2', 'W3', 'H1', 'H3'}, boat=right)
# Step 25: Move {'H2', 'H1'} - State(L={'W2'}, I={'W1', 'H2', 'H1'}, R={'W3', 'H3'}, boat=island)
# Step 26: Move {'H2', 'H1'} - State(L={'H2', 'H1', 'W2'}, I={'W1'}, R={'W3', 'H3'}, boat=left)
# Step 27: Move {'W2'} - State(L={'H2', 'H1'}, I={'W1', 'W2'}, R={'W3', 'H3'}, boat=island)
# Step 28: Move {'W1', 'W2'} - State(L={'W1', 'H2', 'H1', 'W2'}, I=set(), R={'W3', 'H3'}, boat=left)
# Step 29: Move {'H2', 'W2'} - State(L={'W1', 'H1'}, I={'H2', 'W2'}, R={'W3', 'H3'}, boat=island)
# Step 30: Move {'H2', 'W2'} - State(L={'W1', 'H1'}, I=set(), R={'H2', 'W3', 'W2', 'H3'}, boat=right)
# Step 31: Move {'W3', 'H3'} - State(L={'W1', 'H1'}, I={'W3', 'H3'}, R={'H2', 'W2'}, boat=island)
# Step 32: Move {'W3', 'H3'} - State(L={'W3', 'W1', 'H1', 'H3'}, I=set(), R={'H2', 'W2'}, boat=left)
# Step 33: Move {'H1', 'H3'} - State(L={'W3', 'W1'}, I={'H1', 'H3'}, R={'H2', 'W2'}, boat=island)
# Step 34: Move {'H1', 'H3'} - State(L={'W1', 'W3'}, I=set(), R={'H2', 'H1', 'W2', 'H3'}, boat=right)
# Step 35: Move {'H2', 'W2'} - State(L={'W1', 'W3'}, I={'H2', 'W2'}, R={'H1', 'H3'}, boat=island)
# Step 36: Move {'H2'} - State(L={'W1', 'W3'}, I={'W2'}, R={'H2', 'H1', 'H3'}, boat=right)
# Step 37: Move {'H2', 'H3'} - State(L={'W1', 'W3'}, I={'H2', 'W2', 'H3'}, R={'H1'}, boat=island)
# Step 38: Move {'H2', 'W2'} - State(L={'W1', 'W3'}, I={'H3'}, R={'H2', 'H1', 'W2'}, boat=right)
# Step 39: Move {'H2', 'H1'} - State(L={'W1', 'W3'}, I={'H2', 'H1', 'H3'}, R={'W2'}, boat=island)
# Step 40: Move {'H1', 'H3'} - State(L={'W1', 'W3', 'H1', 'H3'}, I={'H2'}, R={'W2'}, boat=left)
# Step 41: Move {'W3', 'H3'} - State(L={'W1', 'H1'}, I={'H2', 'W3', 'H3'}, R={'W2'}, boat=island)
# Step 42: Move {'H2', 'H3'} - State(L={'W1', 'H1'}, I={'W3'}, R={'H2', 'W2', 'H3'}, boat=right)
# Step 43: Move {'W2'} - State(L={'W1', 'H1'}, I={'W3', 'W2'}, R={'H2', 'H3'}, boat=island)
# Step 44: Move {'W3'} - State(L={'W1', 'H1'}, I={'W2'}, R={'H2', 'W3', 'H3'}, boat=right)
# Step 45: Move {'H2', 'H3'} - State(L={'W1', 'H1'}, I={'H2', 'W2', 'H3'}, R={'W3'}, boat=island)
# Step 46: Move {'H2', 'H3'} - State(L={'W1', 'H2', 'H1', 'H3'}, I={'W2'}, R={'W3'}, boat=left)
# Step 47: Move {'H2'} - State(L={'W1', 'H1', 'H3'}, I={'H2', 'W2'}, R={'W3'}, boat=island)
# Step 48: Move {'H2', 'W2'} - State(L={'H2', 'W1', 'H1', 'W2', 'H3'}, I=set(), R={'W3'}, boat=left)
# Step 49: Move {'W1', 'W2'} - State(L={'H2', 'H1', 'H3'}, I={'W1', 'W2'}, R={'W3'}, boat=island)
# Step 50: Move {'W1', 'W2'} - State(L={'H2', 'H1', 'H3'}, I=set(), R={'W1', 'W3', 'W2'}, boat=right)
# Step 51: Move {'W3', 'W2'} - State(L={'H2', 'H1', 'H3'}, I={'W3', 'W2'}, R={'W1'}, boat=island)
# Step 52: Move {'W2'} - State(L={'H2', 'H1', 'H3'}, I={'W3'}, R={'W1', 'W2'}, boat=right)
# Step 53: Move {'W1', 'W2'} - State(L={'H2', 'H1', 'H3'}, I={'W1', 'W3', 'W2'}, R=set(), boat=island)
# Step 54: Move {'W3', 'W2'} - State(L={'H2', 'H1', 'H3'}, I={'W1'}, R={'W3', 'W2'}, boat=right)
# Step 55: Move {'W3'} - State(L={'H2', 'H1', 'H3'}, I={'W1', 'W3'}, R={'W2'}, boat=island)
# Step 56: Move {'W1', 'W3'} - State(L={'H2', 'W3', 'W1', 'H1', 'H3'}, I=set(), R={'W2'}, boat=left)
# Step 57: Move {'W1', 'H1'} - State(L={'H2', 'W3', 'H3'}, I={'W1', 'H1'}, R={'W2'}, boat=island)
# Step 58: Move {'H1'} - State(L={'H2', 'W3', 'H1', 'H3'}, I={'W1'}, R={'W2'}, boat=left)
# Step 59: Move {'H2', 'H1'} - State(L={'W3', 'H3'}, I={'W1', 'H2', 'H1'}, R={'W2'}, boat=island)
# Step 60: Move {'H2', 'H1'} - State(L={'W3', 'H3'}, I={'W1'}, R={'H2', 'H1', 'W2'}, boat=right)
# Step 61: Move {'W2'} - State(L={'W3', 'H3'}, I={'W1', 'W2'}, R={'H2', 'H1'}, boat=island)
# Step 62: Move {'W1', 'W2'} - State(L={'W3', 'H3'}, I=set(), R={'W1', 'H2', 'H1', 'W2'}, boat=right)
# Step 63: Move {'H2', 'W2'} - State(L={'W3', 'H3'}, I={'H2', 'W2'}, R={'W1', 'H1'}, boat=island)
# Step 64: Move {'H2', 'W2'} - State(L={'H2', 'W3', 'W2', 'H3'}, I=set(), R={'W1', 'H1'}, boat=left)
# Step 65: Move {'W3', 'W2'} - State(L={'H2', 'H3'}, I={'W3', 'W2'}, R={'W1', 'H1'}, boat=island)
# Step 66: Move {'W3'} - State(L={'H2', 'W3', 'H3'}, I={'W2'}, R={'W1', 'H1'}, boat=left)
# Step 67: Move {'H2', 'H3'} - State(L={'W3'}, I={'H2', 'W2', 'H3'}, R={'W1', 'H1'}, boat=island)
# Step 68: Move {'H2', 'H3'} - State(L={'W3'}, I={'W2'}, R={'W1', 'H2', 'H1', 'H3'}, boat=right)
# Step 69: Move {'H2'} - State(L={'W3'}, I={'H2', 'W2'}, R={'W1', 'H1', 'H3'}, boat=island)
# Step 70: Move {'H2', 'W2'} - State(L={'W3'}, I=set(), R={'H2', 'W1', 'H1', 'W2', 'H3'}, boat=right)
# Step 71: Move {'W1', 'W2'} - State(L={'W3'}, I={'W1', 'W2'}, R={'H2', 'H1', 'H3'}, boat=island)
# Step 72: Move {'W1', 'W2'} - State(L={'W1', 'W3', 'W2'}, I=set(), R={'H2', 'H1', 'H3'}, boat=left)
# Step 73: Move {'W3', 'W2'} - State(L={'W1'}, I={'W3', 'W2'}, R={'H2', 'H1', 'H3'}, boat=island)
# Step 74: Move {'W3', 'W2'} - State(L={'W1'}, I=set(), R={'H2', 'W3', 'H1', 'W2', 'H3'}, boat=right)
# Step 75: Move {'W3', 'H3'} - State(L={'W1'}, I={'W3', 'H3'}, R={'H2', 'H1', 'W2'}, boat=island)
# Step 76: Move {'H3'} - State(L={'W1'}, I={'W3'}, R={'H2', 'H1', 'W2', 'H3'}, boat=right)
# Step 77: Move {'H1', 'H3'} - State(L={'W1'}, I={'W3', 'H1', 'H3'}, R={'H2', 'W2'}, boat=island)
# Step 78: Move {'H1', 'H3'} - State(L={'W1', 'H1', 'H3'}, I={'W3'}, R={'H2', 'W2'}, boat=left)
# Step 79: Move {'W1'} - State(L={'H1', 'H3'}, I={'W1', 'W3'}, R={'H2', 'W2'}, boat=island)
# Step 80: Move {'W3'} - State(L={'W3', 'H1', 'H3'}, I={'W1'}, R={'H2', 'W2'}, boat=left)
# Step 81: Move {'H1', 'H3'} - State(L={'W3'}, I={'W1', 'H1', 'H3'}, R={'H2', 'W2'}, boat=island)
# Step 82: Move {'W1', 'H1'} - State(L={'W3'}, I={'H3'}, R={'W1', 'H2', 'H1', 'W2'}, boat=right)
# Step 83: Move {'H2', 'H1'} - State(L={'W3'}, I={'H2', 'H1', 'H3'}, R={'W1', 'W2'}, boat=island)
# Step 84: Move {'H1', 'H3'} - State(L={'W3', 'H1', 'H3'}, I={'H2'}, R={'W1', 'W2'}, boat=left)
# Step 85: Move {'W3', 'H3'} - State(L={'H1'}, I={'H2', 'W3', 'H3'}, R={'W1', 'W2'}, boat=island)
# Step 86: Move {'H2', 'H3'} - State(L={'H2', 'H1', 'H3'}, I={'W3'}, R={'W1', 'W2'}, boat=left)
# Step 87: Move {'H1', 'H3'} - State(L={'H2'}, I={'W3', 'H1', 'H3'}, R={'W1', 'W2'}, boat=island)
# Step 88: Move {'H1'} - State(L={'H2', 'H1'}, I={'W3', 'H3'}, R={'W1', 'W2'}, boat=left)
# Step 89: Move {'H2', 'H1'} - State(L=set(), I={'H2', 'W3', 'H1', 'H3'}, R={'W1', 'W2'}, boat=island)
# Step 90: Move {'H2', 'H1'} - State(L=set(), I={'W3', 'H3'}, R={'W1', 'H2', 'H1', 'W2'}, boat=right)
# Step 91: Move {'H2', 'W2'} - State(L=set(), I={'H2', 'W3', 'W2', 'H3'}, R={'W1', 'H1'}, boat=island)
# Step 92: Move {'W3', 'H3'} - State(L=set(), I={'H2', 'W2'}, R={'W3', 'W1', 'H1', 'H3'}, boat=right)
# Step 93: Move {'H1', 'H3'} - State(L=set(), I={'H2', 'H1', 'W2', 'H3'}, R={'W3', 'W1'}, boat=island)
# Step 94: Move {'H1', 'H3'} - State(L={'H1', 'H3'}, I={'H2', 'W2'}, R={'W1', 'W3'}, boat=left)
# Step 95: Move {'H1'} - State(L={'H3'}, I={'H2', 'H1', 'W2'}, R={'W1', 'W3'}, boat=island)
# Step 96: Move {'W2'} - State(L={'H3'}, I={'H2', 'H1'}, R={'W1', 'W3', 'W2'}, boat=right)
# Step 97: Move {'W1', 'W2'} - State(L={'H3'}, I={'W1', 'H2', 'H1', 'W2'}, R={'W3'}, boat=island)
# Step 98: Move {'H2', 'W2'} - State(L={'H2', 'W2', 'H3'}, I={'W1', 'H1'}, R={'W3'}, boat=left)
# Step 99: Move {'H2', 'H3'} - State(L={'W2'}, I={'W1', 'H2', 'H1', 'H3'}, R={'W3'}, boat=island)
# Step 100: Move {'H2', 'H3'} - State(L={'W2'}, I={'W1', 'H1'}, R={'H2', 'W3', 'H3'}, boat=right)
# Step 101: Move {'W3', 'H3'} - State(L={'W2'}, I={'W3', 'W1', 'H1', 'H3'}, R={'H2'}, boat=island)
# Step 102: Move {'W1', 'H1'} - State(L={'W2'}, I={'W3', 'H3'}, R={'W1', 'H2', 'H1'}, boat=right)
# Step 103: Move {'H2', 'H1'} - State(L={'W2'}, I={'H2', 'W3', 'H1', 'H3'}, R={'W1'}, boat=island)
# Step 104: Move {'H2', 'H1'} - State(L={'H2', 'H1', 'W2'}, I={'W3', 'H3'}, R={'W1'}, boat=left)
# Step 105: Move {'H2', 'W2'} - State(L={'H1'}, I={'H2', 'W3', 'W2', 'H3'}, R={'W1'}, boat=island)
# Step 106: Move {'W3', 'H3'} - State(L={'W3', 'H1', 'H3'}, I={'H2', 'W2'}, R={'W1'}, boat=left)
# Step 107: Move {'H1', 'H3'} - State(L={'W3'}, I={'H2', 'H1', 'W2', 'H3'}, R={'W1'}, boat=island)
# Step 108: Move {'H1', 'H3'} - State(L={'W3'}, I={'H2', 'W2'}, R={'W1', 'H1', 'H3'}, boat=right)
# Step 109: Move {'W1', 'H1'} - State(L={'W3'}, I={'W1', 'H2', 'H1', 'W2'}, R={'H3'}, boat=island)
# Step 110: Move {'H2', 'W2'} - State(L={'W3'}, I={'W1', 'H1'}, R={'H2', 'W2', 'H3'}, boat=right)
# Step 111: Move {'H2', 'H3'} - State(L={'W3'}, I={'W1', 'H2', 'H1', 'H3'}, R={'W2'}, boat=island)
# Step 112: Move {'H2', 'H3'} - State(L={'H2', 'W3', 'H3'}, I={'W1', 'H1'}, R={'W2'}, boat=left)
# Step 113: Move {'W3', 'H3'} - State(L={'H2'}, I={'W3', 'W1', 'H1', 'H3'}, R={'W2'}, boat=island)
# Step 114: Move {'W1', 'H1'} - State(L={'W1', 'H2', 'H1'}, I={'W3', 'H3'}, R={'W2'}, boat=left)
# Step 115: Move {'H2', 'H1'} - State(L={'W1'}, I={'H2', 'W3', 'H1', 'H3'}, R={'W2'}, boat=island)
# Step 116: Move {'H2', 'H1'} - State(L={'W1'}, I={'W3', 'H3'}, R={'H2', 'H1', 'W2'}, boat=right)
# Step 117: Move {'H2', 'W2'} - State(L={'W1'}, I={'H2', 'W3', 'W2', 'H3'}, R={'H1'}, boat=island)
# Step 118: Move {'W3', 'H3'} - State(L={'W1'}, I={'H2', 'W2'}, R={'W3', 'H1', 'H3'}, boat=right)
# Step 119: Move {'H1', 'H3'} - State(L={'W1'}, I={'H2', 'H1', 'W2', 'H3'}, R={'W3'}, boat=island)
# Step 120: Move {'H3'} - State(L={'W1'}, I={'H2', 'H1', 'W2'}, R={'W3', 'H3'}, boat=right)
# Step 121: Move {'W3', 'H3'} - State(L={'W1'}, I={'H2', 'W3', 'H1', 'W2', 'H3'}, R=set(), boat=island)
# Step 122: Move {'W3', 'W2'} - State(L={'W1', 'W3', 'W2'}, I={'H2', 'H1', 'H3'}, R=set(), boat=left)
# Step 123: Move {'W1', 'W2'} - State(L={'W3'}, I={'H2', 'W1', 'H1', 'W2', 'H3'}, R=set(), boat=island)
# Step 124: Move {'H3'} - State(L={'W3', 'H3'}, I={'H2', 'W1', 'H1', 'W2'}, R=set(), boat=left)
# Step 125: Move {'W3', 'H3'} - State(L=set(), I={'H2', 'W3', 'W1', 'H1', 'W2', 'H3'}, R=set(), boat=island)
# Step 126: Move {'W1', 'W2'} - State(L=set(), I={'H2', 'W3', 'H1', 'H3'}, R={'W1', 'W2'}, boat=right)
# Step 127: Move {'W2'} - State(L=set(), I={'H2', 'W3', 'H1', 'W2', 'H3'}, R={'W1'}, boat=island)
# Step 128: Move {'W3', 'W2'} - State(L=set(), I={'H2', 'H1', 'H3'}, R={'W1', 'W3', 'W2'}, boat=right)
# Step 129: Move {'W1'} - State(L=set(), I={'W1', 'H2', 'H1', 'H3'}, R={'W3', 'W2'}, boat=island)
# Step 130: Move {'H2', 'H3'} - State(L=set(), I={'W1', 'H1'}, R={'H2', 'W3', 'W2', 'H3'}, boat=right)
# Step 131: Move {'W3', 'H3'} - State(L=set(), I={'W3', 'W1', 'H1', 'H3'}, R={'H2', 'W2'}, boat=island)
# Step 132: Move {'H1', 'H3'} - State(L=set(), I={'W3', 'W1'}, R={'H2', 'H1', 'W2', 'H3'}, boat=right)
# Step 133: Move {'W2'} - State(L=set(), I={'W1', 'W3', 'W2'}, R={'H2', 'H1', 'H3'}, boat=island)
# Step 134: Move {'W3', 'W2'} - State(L=set(), I={'W1'}, R={'H2', 'W3', 'H1', 'W2', 'H3'}, boat=right)
# Step 135: Move {'W2'} - State(L=set(), I={'W1', 'W2'}, R={'H2', 'W3', 'H1', 'H3'}, boat=island)
# Step 136: Move {'W1', 'W2'} - State(L=set(), I=set(), R={'H2', 'W3', 'W1', 'H1', 'W2', 'H3'}, boat=right)
#
# Final state:
# State(L=set(), I=set(), R={'H2', 'W3', 'W1', 'H1', 'W2', 'H3'}, boat=right)

# %%
# Task 3:
def backtrack(state, path, visited):
    if state.is_goal():
        return path

    visited.add(state)

    for child_state, passengers in state.generate_children():
        if child_state not in visited:
            result = backtrack(child_state, path + [(child_state, passengers)], visited)
            if result:
                return result

    return None


solution = backtrack(initial_state, [(initial_state, None)], set())

if solution:
    print("Goal reached!\n")
    print(f"Initial state:\n{initial_state}\n")
    for step_num, (state, move) in enumerate(solution, 1):
        if move is not None:
            print(f"Step {step_num - 1}: Move {move} - {state}")
    print(f"\nFinal state:\n{state}")
else:
    print("No solution found.")
# Out:
# Goal reached!
#
# Initial state:
# State(L={'H2', 'W3', 'W1', 'H1', 'W2', 'H3'}, I=set(), R=set(), boat=left)
#
# Step 1: Move {'H2', 'W2'} - State(L={'W3', 'W1', 'H1', 'H3'}, I={'H2', 'W2'}, R=set(), boat=island)
# Step 2: Move {'H2'} - State(L={'H2', 'W3', 'W1', 'H1', 'H3'}, I={'W2'}, R=set(), boat=left)
# Step 3: Move {'W3'} - State(L={'H2', 'W1', 'H1', 'H3'}, I={'W3', 'W2'}, R=set(), boat=island)
# Step 4: Move {'W2'} - State(L={'H2', 'W1', 'H1', 'W2', 'H3'}, I={'W3'}, R=set(), boat=left)
# Step 5: Move {'W1'} - State(L={'H2', 'H1', 'W2', 'H3'}, I={'W1', 'W3'}, R=set(), boat=island)
# Step 6: Move {'W3'} - State(L={'H2', 'W3', 'H1', 'W2', 'H3'}, I={'W1'}, R=set(), boat=left)
# Step 7: Move {'H1'} - State(L={'H2', 'W3', 'W2', 'H3'}, I={'W1', 'H1'}, R=set(), boat=island)
# Step 8: Move {'W1', 'H1'} - State(L={'H2', 'W3', 'W2', 'H3'}, I=set(), R={'W1', 'H1'}, boat=right)
# Step 9: Move {'H1'} - State(L={'H2', 'W3', 'W2', 'H3'}, I={'H1'}, R={'W1'}, boat=island)
# Step 10: Move {'H1'} - State(L={'H2', 'W3', 'H1', 'W2', 'H3'}, I=set(), R={'W1'}, boat=left)
# Step 11: Move {'W3'} - State(L={'H2', 'H1', 'W2', 'H3'}, I={'W3'}, R={'W1'}, boat=island)
# Step 12: Move {'W3'} - State(L={'H2', 'H1', 'W2', 'H3'}, I=set(), R={'W1', 'W3'}, boat=right)
# Step 13: Move {'W1'} - State(L={'H2', 'H1', 'W2', 'H3'}, I={'W1'}, R={'W3'}, boat=island)
# Step 14: Move {'W1'} - State(L={'H2', 'W1', 'H1', 'W2', 'H3'}, I=set(), R={'W3'}, boat=left)
# Step 15: Move {'W2'} - State(L={'H2', 'W1', 'H1', 'H3'}, I={'W2'}, R={'W3'}, boat=island)
# Step 16: Move {'W2'} - State(L={'W1', 'H2', 'H1', 'H3'}, I=set(), R={'W3', 'W2'}, boat=right)
# Step 17: Move {'W3'} - State(L={'W1', 'H2', 'H1', 'H3'}, I={'W3'}, R={'W2'}, boat=island)
# Step 18: Move {'W3'} - State(L={'H2', 'W3', 'W1', 'H1', 'H3'}, I=set(), R={'W2'}, boat=left)
# Step 19: Move {'W1', 'W3'} - State(L={'H2', 'H1', 'H3'}, I={'W1', 'W3'}, R={'W2'}, boat=island)
# Step 20: Move {'W1'} - State(L={'W1', 'H2', 'H1', 'H3'}, I={'W3'}, R={'W2'}, boat=left)
# Step 21: Move {'H2', 'H3'} - State(L={'W1', 'H1'}, I={'H2', 'W3', 'H3'}, R={'W2'}, boat=island)
# Step 22: Move {'H2'} - State(L={'W1', 'H2', 'H1'}, I={'W3', 'H3'}, R={'W2'}, boat=left)
# Step 23: Move {'W1', 'H1'} - State(L={'H2'}, I={'W1', 'W3', 'H1', 'H3'}, R={'W2'}, boat=island)
# Step 24: Move {'W1', 'W3'} - State(L={'H2'}, I={'H1', 'H3'}, R={'W1', 'W3', 'W2'}, boat=right)
# Step 25: Move {'W1'} - State(L={'H2'}, I={'W1', 'H1', 'H3'}, R={'W3', 'W2'}, boat=island)
# Step 26: Move {'H3'} - State(L={'H2', 'H3'}, I={'W1', 'H1'}, R={'W3', 'W2'}, boat=left)
# Step 27: Move {'H2'} - State(L={'H3'}, I={'W1', 'H2', 'H1'}, R={'W3', 'W2'}, boat=island)
# Step 28: Move {'W1'} - State(L={'H3'}, I={'H2', 'H1'}, R={'W1', 'W3', 'W2'}, boat=right)
# Step 29: Move {'W2'} - State(L={'H3'}, I={'H2', 'H1', 'W2'}, R={'W1', 'W3'}, boat=island)
# Step 30: Move {'H1'} - State(L={'H1', 'H3'}, I={'H2', 'W2'}, R={'W1', 'W3'}, boat=left)
# Step 31: Move {'H3'} - State(L={'H1'}, I={'H2', 'W2', 'H3'}, R={'W1', 'W3'}, boat=island)
# Step 32: Move {'W2'} - State(L={'H1'}, I={'H2', 'H3'}, R={'W1', 'W3', 'W2'}, boat=right)
# Step 33: Move {'W3'} - State(L={'H1'}, I={'H2', 'W3', 'H3'}, R={'W1', 'W2'}, boat=island)
# Step 34: Move {'H2'} - State(L={'H2', 'H1'}, I={'W3', 'H3'}, R={'W1', 'W2'}, boat=left)
# Step 35: Move {'H1'} - State(L={'H2'}, I={'W3', 'H1', 'H3'}, R={'W1', 'W2'}, boat=island)
# Step 36: Move {'W3', 'H3'} - State(L={'H2', 'W3', 'H3'}, I={'H1'}, R={'W1', 'W2'}, boat=left)
# Step 37: Move {'H2'} - State(L={'W3', 'H3'}, I={'H2', 'H1'}, R={'W1', 'W2'}, boat=island)
# Step 38: Move {'H1'} - State(L={'W3', 'H1', 'H3'}, I={'H2'}, R={'W1', 'W2'}, boat=left)
# Step 39: Move {'H1', 'H3'} - State(L={'W3'}, I={'H2', 'H1', 'H3'}, R={'W1', 'W2'}, boat=island)
# Step 40: Move {'H3'} - State(L={'W3', 'H3'}, I={'H2', 'H1'}, R={'W1', 'W2'}, boat=left)
# Step 41: Move {'W3', 'H3'} - State(L=set(), I={'W3', 'H2', 'H1', 'H3'}, R={'W1', 'W2'}, boat=island)
# Step 42: Move {'W3'} - State(L=set(), I={'H2', 'H1', 'H3'}, R={'W1', 'W3', 'W2'}, boat=right)
# Step 43: Move {'W1'} - State(L=set(), I={'W1', 'H2', 'H1', 'H3'}, R={'W3', 'W2'}, boat=island)
# Step 44: Move {'W1', 'H1'} - State(L={'W1', 'H1'}, I={'H2', 'H3'}, R={'W3', 'W2'}, boat=left)
# Step 45: Move {'H1'} - State(L={'W1'}, I={'H2', 'H1', 'H3'}, R={'W3', 'W2'}, boat=island)
# Step 46: Move {'H2', 'H1'} - State(L={'W1', 'H2', 'H1'}, I={'H3'}, R={'W3', 'W2'}, boat=left)
# Step 47: Move {'H2'} - State(L={'W1', 'H1'}, I={'H2', 'H3'}, R={'W3', 'W2'}, boat=island)
# Step 48: Move {'H2', 'H3'} - State(L={'W1', 'H2', 'H1', 'H3'}, I=set(), R={'W3', 'W2'}, boat=left)
# Step 49: Move {'W1'} - State(L={'H2', 'H1', 'H3'}, I={'W1'}, R={'W3', 'W2'}, boat=island)
# Step 50: Move {'W1'} - State(L={'H2', 'H1', 'H3'}, I=set(), R={'W1', 'W3', 'W2'}, boat=right)
# Step 51: Move {'W2'} - State(L={'H2', 'H1', 'H3'}, I={'W2'}, R={'W1', 'W3'}, boat=island)
# Step 52: Move {'W2'} - State(L={'H2', 'H1', 'W2', 'H3'}, I=set(), R={'W1', 'W3'}, boat=left)
# Step 53: Move {'H1', 'H3'} - State(L={'H2', 'W2'}, I={'H1', 'H3'}, R={'W1', 'W3'}, boat=island)
# Step 54: Move {'H1'} - State(L={'H2', 'H1', 'W2'}, I={'H3'}, R={'W1', 'W3'}, boat=left)
# Step 55: Move {'H2', 'H1'} - State(L={'W2'}, I={'H2', 'H1', 'H3'}, R={'W1', 'W3'}, boat=island)
# Step 56: Move {'H2'} - State(L={'H2', 'W2'}, I={'H1', 'H3'}, R={'W1', 'W3'}, boat=left)
# Step 57: Move {'H2', 'W2'} - State(L=set(), I={'H2', 'H1', 'W2', 'H3'}, R={'W1', 'W3'}, boat=island)
# Step 58: Move {'H1', 'H3'} - State(L=set(), I={'H2', 'W2'}, R={'W1', 'W3', 'H1', 'H3'}, boat=right)
# Step 59: Move {'W1', 'H1'} - State(L=set(), I={'W1', 'H2', 'H1', 'W2'}, R={'W3', 'H3'}, boat=island)
# Step 60: Move {'W1', 'H1'} - State(L={'W1', 'H1'}, I={'H2', 'W2'}, R={'W3', 'H3'}, boat=left)
# Step 61: Move {'H1'} - State(L={'W1'}, I={'H2', 'H1', 'W2'}, R={'W3', 'H3'}, boat=island)
# Step 62: Move {'H1'} - State(L={'W1'}, I={'H2', 'W2'}, R={'W3', 'H1', 'H3'}, boat=right)
# Step 63: Move {'W3', 'H3'} - State(L={'W1'}, I={'H2', 'W3', 'W2', 'H3'}, R={'H1'}, boat=island)
# Step 64: Move {'H2', 'W2'} - State(L={'W1'}, I={'W3', 'H3'}, R={'H2', 'H1', 'W2'}, boat=right)
# Step 65: Move {'H1'} - State(L={'W1'}, I={'W3', 'H1', 'H3'}, R={'H2', 'W2'}, boat=island)
# Step 66: Move {'W3'} - State(L={'W1', 'W3'}, I={'H1', 'H3'}, R={'H2', 'W2'}, boat=left)
# Step 67: Move {'W1'} - State(L={'W3'}, I={'W1', 'H1', 'H3'}, R={'H2', 'W2'}, boat=island)
# Step 68: Move {'H3'} - State(L={'W3', 'H3'}, I={'W1', 'H1'}, R={'H2', 'W2'}, boat=left)
# Step 69: Move {'W3', 'H3'} - State(L=set(), I={'W3', 'W1', 'H1', 'H3'}, R={'H2', 'W2'}, boat=island)
# Step 70: Move {'W1', 'H1'} - State(L=set(), I={'W3', 'H3'}, R={'W1', 'H2', 'H1', 'W2'}, boat=right)
# Step 71: Move {'H2', 'W2'} - State(L=set(), I={'H2', 'W3', 'W2', 'H3'}, R={'W1', 'H1'}, boat=island)
# Step 72: Move {'H2', 'W2'} - State(L={'H2', 'W2'}, I={'W3', 'H3'}, R={'W1', 'H1'}, boat=left)
# Step 73: Move {'H2'} - State(L={'W2'}, I={'H2', 'W3', 'H3'}, R={'W1', 'H1'}, boat=island)
# Step 74: Move {'H2'} - State(L={'W2'}, I={'W3', 'H3'}, R={'W1', 'H2', 'H1'}, boat=right)
# Step 75: Move {'W1', 'H1'} - State(L={'W2'}, I={'W1', 'W3', 'H1', 'H3'}, R={'H2'}, boat=island)
# Step 76: Move {'W1', 'W3'} - State(L={'W1', 'W3', 'W2'}, I={'H1', 'H3'}, R={'H2'}, boat=left)
# Step 77: Move {'W1'} - State(L={'W3', 'W2'}, I={'W1', 'H1', 'H3'}, R={'H2'}, boat=island)
# Step 78: Move {'H3'} - State(L={'W3', 'W2'}, I={'W1', 'H1'}, R={'H2', 'H3'}, boat=right)
# Step 79: Move {'H2'} - State(L={'W3', 'W2'}, I={'W1', 'H2', 'H1'}, R={'H3'}, boat=island)
# Step 80: Move {'W1'} - State(L={'W1', 'W3', 'W2'}, I={'H2', 'H1'}, R={'H3'}, boat=left)
# Step 81: Move {'W2'} - State(L={'W1', 'W3'}, I={'H2', 'H1', 'W2'}, R={'H3'}, boat=island)
# Step 82: Move {'H1'} - State(L={'W1', 'W3'}, I={'H2', 'W2'}, R={'H1', 'H3'}, boat=right)
# Step 83: Move {'H3'} - State(L={'W1', 'W3'}, I={'H2', 'W2', 'H3'}, R={'H1'}, boat=island)
# Step 84: Move {'W2'} - State(L={'W1', 'W3', 'W2'}, I={'H2', 'H3'}, R={'H1'}, boat=left)
# Step 85: Move {'W3'} - State(L={'W1', 'W2'}, I={'H2', 'W3', 'H3'}, R={'H1'}, boat=island)
# Step 86: Move {'H2'} - State(L={'W1', 'W2'}, I={'W3', 'H3'}, R={'H2', 'H1'}, boat=right)
# Step 87: Move {'H1'} - State(L={'W1', 'W2'}, I={'W3', 'H1', 'H3'}, R={'H2'}, boat=island)
# Step 88: Move {'W3', 'H3'} - State(L={'W1', 'W2'}, I={'H1'}, R={'H2', 'W3', 'H3'}, boat=right)
# Step 89: Move {'H2'} - State(L={'W1', 'W2'}, I={'H2', 'H1'}, R={'W3', 'H3'}, boat=island)
# Step 90: Move {'H1'} - State(L={'W1', 'W2'}, I={'H2'}, R={'W3', 'H1', 'H3'}, boat=right)
# Step 91: Move {'H1', 'H3'} - State(L={'W1', 'W2'}, I={'H2', 'H1', 'H3'}, R={'W3'}, boat=island)
# Step 92: Move {'H3'} - State(L={'W1', 'W2'}, I={'H2', 'H1'}, R={'W3', 'H3'}, boat=right)
# Step 93: Move {'W3', 'H3'} - State(L={'W1', 'W2'}, I={'W3', 'H2', 'H1', 'H3'}, R=set(), boat=island)
# Step 94: Move {'W3'} - State(L={'W1', 'W3', 'W2'}, I={'H2', 'H1', 'H3'}, R=set(), boat=left)
# Step 95: Move {'W1'} - State(L={'W3', 'W2'}, I={'W1', 'H2', 'H1', 'H3'}, R=set(), boat=island)
# Step 96: Move {'W1', 'H1'} - State(L={'W3', 'W2'}, I={'H2', 'H3'}, R={'W1', 'H1'}, boat=right)
# Step 97: Move {'H1'} - State(L={'W3', 'W2'}, I={'H2', 'H1', 'H3'}, R={'W1'}, boat=island)
# Step 98: Move {'H2', 'H1'} - State(L={'W3', 'W2'}, I={'H3'}, R={'W1', 'H2', 'H1'}, boat=right)
# Step 99: Move {'H2'} - State(L={'W3', 'W2'}, I={'H2', 'H3'}, R={'W1', 'H1'}, boat=island)
# Step 100: Move {'H2', 'H3'} - State(L={'H2', 'W3', 'W2', 'H3'}, I=set(), R={'W1', 'H1'}, boat=left)
# Step 101: Move {'H2', 'W2'} - State(L={'W3', 'H3'}, I={'H2', 'W2'}, R={'W1', 'H1'}, boat=island)
# Step 102: Move {'H2'} - State(L={'H2', 'W3', 'H3'}, I={'W2'}, R={'W1', 'H1'}, boat=left)
# Step 103: Move {'W3'} - State(L={'H2', 'H3'}, I={'W3', 'W2'}, R={'W1', 'H1'}, boat=island)
# Step 104: Move {'W2'} - State(L={'H2', 'W2', 'H3'}, I={'W3'}, R={'W1', 'H1'}, boat=left)
# Step 105: Move {'H3'} - State(L={'H2', 'W2'}, I={'W3', 'H3'}, R={'W1', 'H1'}, boat=island)
# Step 106: Move {'H3'} - State(L={'H2', 'W2'}, I={'W3'}, R={'W1', 'H1', 'H3'}, boat=right)
# Step 107: Move {'W1'} - State(L={'H2', 'W2'}, I={'W1', 'W3'}, R={'H1', 'H3'}, boat=island)
# Step 108: Move {'W3'} - State(L={'H2', 'W2'}, I={'W1'}, R={'W3', 'H1', 'H3'}, boat=right)
# Step 109: Move {'H1'} - State(L={'H2', 'W2'}, I={'W1', 'H1'}, R={'W3', 'H3'}, boat=island)
# Step 110: Move {'H1'} - State(L={'H2', 'H1', 'W2'}, I={'W1'}, R={'W3', 'H3'}, boat=left)
# Step 111: Move {'W2'} - State(L={'H2', 'H1'}, I={'W1', 'W2'}, R={'W3', 'H3'}, boat=island)
# Step 112: Move {'W1'} - State(L={'W1', 'H2', 'H1'}, I={'W2'}, R={'W3', 'H3'}, boat=left)
# Step 113: Move {'H2'} - State(L={'W1', 'H1'}, I={'H2', 'W2'}, R={'W3', 'H3'}, boat=island)
# Step 114: Move {'H2'} - State(L={'W1', 'H1'}, I={'W2'}, R={'H2', 'W3', 'H3'}, boat=right)
# Step 115: Move {'W3'} - State(L={'W1', 'H1'}, I={'W3', 'W2'}, R={'H2', 'H3'}, boat=island)
# Step 116: Move {'W2'} - State(L={'W1', 'H1'}, I={'W3'}, R={'H2', 'W2', 'H3'}, boat=right)
# Step 117: Move {'H3'} - State(L={'W1', 'H1'}, I={'W3', 'H3'}, R={'H2', 'W2'}, boat=island)
# Step 118: Move {'H3'} - State(L={'W1', 'H1', 'H3'}, I={'W3'}, R={'H2', 'W2'}, boat=left)
# Step 119: Move {'W1'} - State(L={'H1', 'H3'}, I={'W1', 'W3'}, R={'H2', 'W2'}, boat=island)
# Step 120: Move {'W3'} - State(L={'W3', 'H1', 'H3'}, I={'W1'}, R={'H2', 'W2'}, boat=left)
# Step 121: Move {'H1'} - State(L={'W3', 'H3'}, I={'W1', 'H1'}, R={'H2', 'W2'}, boat=island)
# Step 122: Move {'H1'} - State(L={'W3', 'H3'}, I={'W1'}, R={'H2', 'H1', 'W2'}, boat=right)
# Step 123: Move {'W2'} - State(L={'W3', 'H3'}, I={'W1', 'W2'}, R={'H2', 'H1'}, boat=island)
# Step 124: Move {'W1'} - State(L={'W3', 'H3'}, I={'W2'}, R={'W1', 'H2', 'H1'}, boat=right)
# Step 125: Move {'H2', 'H1'} - State(L={'W3', 'H3'}, I={'H2', 'H1', 'W2'}, R={'W1'}, boat=island)
# Step 126: Move {'H1'} - State(L={'W3', 'H1', 'H3'}, I={'H2', 'W2'}, R={'W1'}, boat=left)
# Step 127: Move {'W3', 'H3'} - State(L={'H1'}, I={'H2', 'W3', 'W2', 'H3'}, R={'W1'}, boat=island)
# Step 128: Move {'H2', 'W2'} - State(L={'H2', 'H1', 'W2'}, I={'W3', 'H3'}, R={'W1'}, boat=left)
# Step 129: Move {'H1'} - State(L={'H2', 'W2'}, I={'W3', 'H1', 'H3'}, R={'W1'}, boat=island)
# Step 130: Move {'W3'} - State(L={'H2', 'W2'}, I={'H1', 'H3'}, R={'W1', 'W3'}, boat=right)
# Step 131: Move {'W1'} - State(L={'H2', 'W2'}, I={'W1', 'H1', 'H3'}, R={'W3'}, boat=island)
# Step 132: Move {'H3'} - State(L={'H2', 'W2', 'H3'}, I={'W1', 'H1'}, R={'W3'}, boat=left)
# Step 133: Move {'H2', 'W2'} - State(L={'H3'}, I={'W1', 'H2', 'H1', 'W2'}, R={'W3'}, boat=island)
# Step 134: Move {'W1', 'H1'} - State(L={'W1', 'H1', 'H3'}, I={'H2', 'W2'}, R={'W3'}, boat=left)
# Step 135: Move {'H3'} - State(L={'W1', 'H1'}, I={'H2', 'W2', 'H3'}, R={'W3'}, boat=island)
# Step 136: Move {'W2'} - State(L={'W1', 'H1'}, I={'H2', 'H3'}, R={'W3', 'W2'}, boat=right)
# Step 137: Move {'W3', 'W2'} - State(L={'W1', 'H1'}, I={'H2', 'W3', 'W2', 'H3'}, R=set(), boat=island)
# Step 138: Move {'H2', 'W2'} - State(L={'W1', 'H2', 'H1', 'W2'}, I={'W3', 'H3'}, R=set(), boat=left)
# Step 139: Move {'W1', 'H1'} - State(L={'H2', 'W2'}, I={'W1', 'W3', 'H1', 'H3'}, R=set(), boat=island)
# Step 140: Move {'W3', 'H3'} - State(L={'H2', 'W3', 'W2', 'H3'}, I={'W1', 'H1'}, R=set(), boat=left)
# Step 141: Move {'H2', 'W2'} - State(L={'W3', 'H3'}, I={'W1', 'H2', 'H1', 'W2'}, R=set(), boat=island)
# Step 142: Move {'W1', 'H1'} - State(L={'W1', 'W3', 'H1', 'H3'}, I={'H2', 'W2'}, R=set(), boat=left)
# Step 143: Move {'H1', 'H3'} - State(L={'W3', 'W1'}, I={'H2', 'H1', 'W2', 'H3'}, R=set(), boat=island)
# Step 144: Move {'H2', 'W2'} - State(L={'W1', 'W3'}, I={'H1', 'H3'}, R={'H2', 'W2'}, boat=right)
# Step 145: Move {'H2'} - State(L={'W1', 'W3'}, I={'H2', 'H1', 'H3'}, R={'W2'}, boat=island)
# Step 146: Move {'H2', 'H1'} - State(L={'W1', 'W3'}, I={'H3'}, R={'H2', 'H1', 'W2'}, boat=right)
# Step 147: Move {'H1'} - State(L={'W1', 'W3'}, I={'H1', 'H3'}, R={'H2', 'W2'}, boat=island)
# Step 148: Move {'H1', 'H3'} - State(L={'W1', 'W3'}, I=set(), R={'H2', 'H1', 'W2', 'H3'}, boat=right)
# Step 149: Move {'W2'} - State(L={'W1', 'W3'}, I={'W2'}, R={'H2', 'H1', 'H3'}, boat=island)
# Step 150: Move {'W2'} - State(L={'W1', 'W3', 'W2'}, I=set(), R={'H2', 'H1', 'H3'}, boat=left)
# Step 151: Move {'W1', 'W3'} - State(L={'W2'}, I={'W1', 'W3'}, R={'H2', 'H1', 'H3'}, boat=island)
# Step 152: Move {'W1'} - State(L={'W1', 'W2'}, I={'W3'}, R={'H2', 'H1', 'H3'}, boat=left)
# Step 153: Move {'W2'} - State(L={'W1'}, I={'W3', 'W2'}, R={'H2', 'H1', 'H3'}, boat=island)
# Step 154: Move {'W3'} - State(L={'W1', 'W3'}, I={'W2'}, R={'H2', 'H1', 'H3'}, boat=left)
# Step 155: Move {'W1'} - State(L={'W3'}, I={'W1', 'W2'}, R={'H2', 'H1', 'H3'}, boat=island)
# Step 156: Move {'W1'} - State(L={'W3'}, I={'W2'}, R={'W1', 'H2', 'H1', 'H3'}, boat=right)
# Step 157: Move {'H2'} - State(L={'W3'}, I={'H2', 'W2'}, R={'W1', 'H1', 'H3'}, boat=island)
# Step 158: Move {'H2', 'W2'} - State(L={'W3'}, I=set(), R={'H2', 'W1', 'H1', 'W2', 'H3'}, boat=right)
# Step 159: Move {'W1'} - State(L={'W3'}, I={'W1'}, R={'H2', 'H1', 'W2', 'H3'}, boat=island)
# Step 160: Move {'W1'} - State(L={'W1', 'W3'}, I=set(), R={'H2', 'H1', 'W2', 'H3'}, boat=left)
# Step 161: Move {'W3'} - State(L={'W1'}, I={'W3'}, R={'H2', 'H1', 'W2', 'H3'}, boat=island)
# Step 162: Move {'W3'} - State(L={'W1'}, I=set(), R={'H2', 'W3', 'H1', 'W2', 'H3'}, boat=right)
# Step 163: Move {'H1'} - State(L={'W1'}, I={'H1'}, R={'H2', 'W3', 'W2', 'H3'}, boat=island)
# Step 164: Move {'H1'} - State(L={'W1', 'H1'}, I=set(), R={'H2', 'W3', 'W2', 'H3'}, boat=left)
# Step 165: Move {'W1', 'H1'} - State(L=set(), I={'W1', 'H1'}, R={'H2', 'W3', 'W2', 'H3'}, boat=island)
# Step 166: Move {'H1'} - State(L=set(), I={'W1'}, R={'H2', 'W3', 'H1', 'W2', 'H3'}, boat=right)
# Step 167: Move {'W3'} - State(L=set(), I={'W1', 'W3'}, R={'H2', 'H1', 'W2', 'H3'}, boat=island)
# Step 168: Move {'W1'} - State(L=set(), I={'W3'}, R={'H2', 'W1', 'H1', 'W2', 'H3'}, boat=right)
# Step 169: Move {'W2'} - State(L=set(), I={'W3', 'W2'}, R={'H2', 'W1', 'H1', 'H3'}, boat=island)
# Step 170: Move {'W3'} - State(L=set(), I={'W2'}, R={'H2', 'W3', 'W1', 'H1', 'H3'}, boat=right)
# Step 171: Move {'H2'} - State(L=set(), I={'H2', 'W2'}, R={'W3', 'W1', 'H1', 'H3'}, boat=island)
# Step 172: Move {'H2', 'W2'} - State(L={'H2', 'W2'}, I=set(), R={'W1', 'W3', 'H1', 'H3'}, boat=left)
# Step 173: Move {'H2'} - State(L={'W2'}, I={'H2'}, R={'W1', 'W3', 'H1', 'H3'}, boat=island)
# Step 174: Move {'H2'} - State(L={'W2'}, I=set(), R={'H2', 'W3', 'W1', 'H1', 'H3'}, boat=right)
# Step 175: Move {'W1'} - State(L={'W2'}, I={'W1'}, R={'H2', 'W3', 'H1', 'H3'}, boat=island)
# Step 176: Move {'W1'} - State(L={'W1', 'W2'}, I=set(), R={'H2', 'W3', 'H1', 'H3'}, boat=left)
# Step 177: Move {'W1', 'W2'} - State(L=set(), I={'W1', 'W2'}, R={'H2', 'W3', 'H1', 'H3'}, boat=island)
# Step 178: Move {'W1', 'W2'} - State(L=set(), I=set(), R={'H2', 'W3', 'W1', 'H1', 'W2', 'H3'}, boat=right)
#
# Final state:
# State(L=set(), I=set(), R={'H2', 'W3', 'W1', 'H1', 'W2', 'H3'}, boat=right)

# %%
# Task 4:
def heuristic(state: State):
    return len(EVERYONE - state.right)

class Node:
    def __init__(self, state: State, parent, cost, move):
        self.state = state
        self.parent = parent
        self.cost = cost
        self.move = move

    def __lt__(self, other):
        return (self.cost + heuristic(self.state)) < (other.cost + heuristic(other.state))

def reconstruct_path(node: Node):
    path = []
    while node:
        path.append((node.state, node.move))
        node = node.parent
    return list(reversed(path))

def a_star_search(initial_state: State):
    heap_queue = []
    heappush(heap_queue, Node(initial_state, None, 0, None))
    visited: Dict[State, int] = {initial_state: 0}

    while heap_queue:
        current_node = heappop(heap_queue)
        current_state = current_node.state

        if current_state.is_goal():
            return reconstruct_path(current_node)

        for child_state, move in current_state.generate_children():
            new_cost = current_node.cost + 1
            if child_state not in visited or new_cost < visited[child_state]:
                visited[child_state] = new_cost
                heappush(heap_queue, Node(child_state, current_node, new_cost, move))

    return None

sol = a_star_search(initial_state)

if sol:
    print("Goal reached!\n")
    print(f"Initial state:\n{sol[0][0]}\n")
    for step_num, (state, move) in enumerate(sol[1:], 1):
        move_str = ', '.join(sorted(move)) if move else "None"
        print(f"Step {step_num}: Move {{{move_str}}} - {state}")
    print(f"\nFinal state:\n{sol[-1][0]}")
else:
    print("No solution found.")
# Out:
# Goal reached!
#
# Initial state:
# State(L={'H2', 'W3', 'W1', 'H1', 'W2', 'H3'}, I=set(), R=set(), boat=left)
#
# Step 1: Move {W1, W2} - State(L={'H2', 'W3', 'H1', 'H3'}, I={'W1', 'W2'}, R=set(), boat=island)
# Step 2: Move {W2} - State(L={'H2', 'W3', 'H1', 'W2', 'H3'}, I={'W1'}, R=set(), boat=left)
# Step 3: Move {W2, W3} - State(L={'H2', 'H1', 'H3'}, I={'W1', 'W3', 'W2'}, R=set(), boat=island)
# Step 4: Move {W2} - State(L={'H2', 'H1', 'W2', 'H3'}, I={'W1', 'W3'}, R=set(), boat=left)
# Step 5: Move {H1, H3} - State(L={'H2', 'W2'}, I={'W1', 'W3', 'H1', 'H3'}, R=set(), boat=island)
# Step 6: Move {W1, W3} - State(L={'H2', 'W2'}, I={'H1', 'H3'}, R={'W1', 'W3'}, boat=right)
# Step 7: Move {W3} - State(L={'H2', 'W2'}, I={'W3', 'H1', 'H3'}, R={'W1'}, boat=island)
# Step 8: Move {H1} - State(L={'H2', 'H1', 'W2'}, I={'W3', 'H3'}, R={'W1'}, boat=left)
# Step 9: Move {H1, H2} - State(L={'W2'}, I={'H2', 'W3', 'H1', 'H3'}, R={'W1'}, boat=island)
# Step 10: Move {H1, H2} - State(L={'W2'}, I={'W3', 'H3'}, R={'W1', 'H2', 'H1'}, boat=right)
# Step 11: Move {H2} - State(L={'W2'}, I={'H2', 'W3', 'H3'}, R={'W1', 'H1'}, boat=island)
# Step 12: Move {H2, H3} - State(L={'W2'}, I={'W3'}, R={'W1', 'H2', 'H1', 'H3'}, boat=right)
# Step 13: Move {H3} - State(L={'W2'}, I={'W3', 'H3'}, R={'W1', 'H2', 'H1'}, boat=island)
# Step 14: Move {H3, W3} - State(L={'W2'}, I=set(), R={'H2', 'W3', 'W1', 'H1', 'H3'}, boat=right)
# Step 15: Move {W3} - State(L={'W2'}, I={'W3'}, R={'H2', 'W1', 'H1', 'H3'}, boat=island)
# Step 16: Move {W3} - State(L={'W3', 'W2'}, I=set(), R={'W1', 'H2', 'H1', 'H3'}, boat=left)
# Step 17: Move {W2, W3} - State(L=set(), I={'W3', 'W2'}, R={'W1', 'H2', 'H1', 'H3'}, boat=island)
# Step 18: Move {W2, W3} - State(L=set(), I=set(), R={'H2', 'W3', 'W1', 'H1', 'W2', 'H3'}, boat=right)
#
# Final state:
# State(L=set(), I=set(), R={'H2', 'W3', 'W1', 'H1', 'W2', 'H3'}, boat=right)
